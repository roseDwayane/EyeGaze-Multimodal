# %% [markdown]
# ## Step 1. Import Library

# %%
from transformers import GPT2TokenizerFast, ViTImageProcessor, VisionEncoderDecoderModel
from PIL import Image
from datasets import load_dataset
import json

# %% [markdown]
# ## Step 2. Make Ground Truth

# %%
# Generate data following the identified pattern

# Define categories and trials
categories = ["A-Single", "B-Single", "Comp", "Coop"]
classes = {"A-Single": "Single", "B-Single": "Single", "Comp": "Competition", "Coop": "Cooperation"}
trials = list(range(1, 41))  # Generating for trials 1 to 10 as an example
pairs = list(range(12, 41))  # Generating for trials 1 to 10 as an example

# Initialize an empty list to store the JSON data
data_generated = []

# Generate data following the pattern
for pair in pairs:
    for trial in trials:
        for category in categories:
            if category == "B-Single" or category == "A-Single":
                data_generated.append({
                    "image1": f"heatmapOn_trajOn_Pair-{pair}-{category}-EYE_trial{str(trial).zfill(2)}_player.png",
                    "image2": f"heatmapOn_trajOn_Pair-{pair}-{category}-EYE_trial{str(trial).zfill(2)}_observer.png",
                    "class": classes[category]
                })
            else:  # For "Comp" and "Coop" categories
                data_generated.append({
                    "image1": f"heatmapOn_trajOn_Pair-{pair}-{category}-EYE_trial{str(trial).zfill(2)}_playerA.png",
                    "image2": f"heatmapOn_trajOn_Pair-{pair}-{category}-EYE_trial{str(trial).zfill(2)}_playerB.png",
                    "class": classes[category]
                })

# Convert to JSON format for viewing
json_data_generated = json.dumps(data_generated, indent=4)

# Save to a JSON file
with open("./image_gt.json", "w") as json_file:
    json_file.write(json_data_generated)

data_generated  # Display the first 1000 characters for preview
# Out:
# [{'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial01_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial01_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial01_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial01_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial01_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial01_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial01_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial01_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial02_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial02_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial02_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial02_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial02_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial02_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial02_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial02_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial03_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial03_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial03_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial03_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial03_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial03_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial03_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial03_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial04_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial04_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial04_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial04_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial04_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial04_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial04_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial04_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial05_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial05_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial05_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial05_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial05_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial05_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial05_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial05_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial06_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial06_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial06_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial06_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial06_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial06_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial06_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial06_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial07_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial07_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial07_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial07_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial07_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial07_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial07_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial07_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial08_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial08_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial08_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial08_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial08_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial08_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial08_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial08_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial09_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial09_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial09_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial09_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial09_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial09_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial09_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial09_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial10_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial10_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial10_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial10_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial10_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial10_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial10_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial10_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial11_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial11_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial11_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial11_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial11_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial11_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial11_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial11_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial12_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial12_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial12_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial12_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial12_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial12_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial12_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial12_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial13_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial13_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial13_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial13_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial13_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial13_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial13_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial13_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial14_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial14_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial14_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial14_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial14_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial14_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial14_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial14_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial15_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial15_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial15_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial15_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial15_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial15_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial15_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial15_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial16_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial16_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial16_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial16_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial16_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial16_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial16_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial16_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial17_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial17_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial17_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial17_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial17_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial17_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial17_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial17_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial18_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial18_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial18_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial18_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial18_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial18_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial18_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial18_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial19_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial19_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial19_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial19_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial19_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial19_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial19_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial19_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial20_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial20_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial20_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial20_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial20_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial20_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial20_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial20_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial21_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial21_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial21_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial21_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial21_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial21_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial21_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial21_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial22_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial22_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial22_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial22_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial22_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial22_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial22_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial22_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial23_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial23_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial23_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial23_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial23_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial23_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial23_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial23_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial24_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial24_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial24_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial24_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial24_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial24_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial24_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial24_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial25_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial25_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial25_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial25_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial25_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial25_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial25_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial25_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial26_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial26_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial26_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial26_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial26_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial26_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial26_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial26_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial27_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial27_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial27_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial27_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial27_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial27_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial27_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial27_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial28_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial28_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial28_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial28_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial28_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial28_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial28_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial28_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial29_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial29_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial29_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial29_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial29_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial29_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial29_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial29_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial30_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial30_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial30_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial30_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial30_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial30_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial30_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial30_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial31_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial31_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial31_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial31_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial31_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial31_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial31_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial31_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial32_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial32_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial32_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial32_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial32_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial32_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial32_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial32_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial33_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial33_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial33_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial33_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial33_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial33_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial33_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial33_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial34_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial34_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial34_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial34_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial34_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial34_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial34_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial34_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial35_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial35_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial35_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial35_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial35_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial35_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial35_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial35_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial36_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial36_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial36_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial36_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial36_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial36_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial36_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial36_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial37_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial37_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial37_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial37_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial37_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial37_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial37_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial37_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial38_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial38_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial38_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial38_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial38_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial38_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial38_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial38_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial39_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial39_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial39_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial39_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial39_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial39_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial39_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial39_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial40_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-A-Single-EYE_trial40_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial40_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-B-Single-EYE_trial40_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial40_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Comp-EYE_trial40_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial40_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-12-Coop-EYE_trial40_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial01_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial01_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial01_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial01_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial01_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial01_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial01_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial01_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial02_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial02_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial02_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial02_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial02_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial02_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial02_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial02_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial03_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial03_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial03_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial03_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial03_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial03_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial03_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial03_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial04_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial04_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial04_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial04_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial04_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial04_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial04_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial04_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial05_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial05_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial05_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial05_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial05_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial05_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial05_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial05_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial06_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial06_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial06_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial06_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial06_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial06_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial06_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial06_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial07_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial07_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial07_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial07_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial07_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial07_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial07_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial07_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial08_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial08_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial08_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial08_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial08_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial08_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial08_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial08_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial09_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial09_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial09_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial09_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial09_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial09_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial09_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial09_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial10_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial10_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial10_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial10_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial10_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial10_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial10_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial10_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial11_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial11_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial11_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial11_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial11_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial11_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial11_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial11_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial12_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial12_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial12_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial12_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial12_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial12_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial12_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial12_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial13_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial13_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial13_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial13_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial13_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial13_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial13_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial13_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial14_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial14_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial14_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial14_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial14_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial14_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial14_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial14_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial15_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial15_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial15_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial15_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial15_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial15_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial15_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial15_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial16_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial16_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial16_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial16_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial16_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial16_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial16_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial16_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial17_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial17_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial17_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial17_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial17_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial17_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial17_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial17_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial18_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial18_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial18_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial18_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial18_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial18_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial18_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial18_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial19_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial19_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial19_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial19_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial19_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial19_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial19_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial19_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial20_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial20_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial20_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial20_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial20_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial20_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial20_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial20_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial21_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial21_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial21_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial21_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial21_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial21_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial21_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial21_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial22_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial22_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial22_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial22_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial22_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial22_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial22_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial22_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial23_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial23_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial23_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial23_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial23_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial23_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial23_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial23_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial24_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial24_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial24_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial24_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial24_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial24_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial24_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial24_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial25_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial25_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial25_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial25_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial25_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial25_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial25_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial25_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial26_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial26_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial26_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial26_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial26_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial26_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial26_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial26_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial27_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial27_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial27_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial27_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial27_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial27_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial27_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial27_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial28_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial28_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial28_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial28_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial28_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial28_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial28_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial28_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial29_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial29_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial29_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial29_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial29_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial29_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial29_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial29_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial30_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial30_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial30_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial30_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial30_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial30_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial30_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial30_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial31_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial31_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial31_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial31_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial31_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial31_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial31_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial31_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial32_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-A-Single-EYE_trial32_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial32_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-B-Single-EYE_trial32_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial32_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Comp-EYE_trial32_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial32_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-13-Coop-EYE_trial32_playerB.png',
#   'class': 'Cooperation'},
# ...
#  {'image1': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial27_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial27_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial27_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial27_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial27_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial27_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial27_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial27_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial28_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial28_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial28_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial28_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial28_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial28_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial28_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial28_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial29_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial29_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial29_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial29_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial29_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial29_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial29_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial29_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial30_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial30_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial30_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial30_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial30_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial30_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial30_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial30_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial31_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial31_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial31_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial31_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial31_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial31_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial31_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial31_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial32_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial32_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial32_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial32_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial32_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial32_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial32_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial32_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial33_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial33_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial33_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial33_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial33_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial33_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial33_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial33_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial34_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial34_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial34_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial34_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial34_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial34_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial34_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial34_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial35_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial35_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial35_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial35_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial35_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial35_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial35_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial35_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial36_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial36_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial36_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial36_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial36_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial36_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial36_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial36_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial37_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial37_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial37_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial37_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial37_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial37_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial37_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial37_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial38_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial38_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial38_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial38_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial38_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial38_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial38_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial38_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial39_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial39_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial39_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial39_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial39_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial39_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial39_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial39_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial40_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-A-Single-EYE_trial40_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial40_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-B-Single-EYE_trial40_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial40_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Comp-EYE_trial40_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial40_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-17-Coop-EYE_trial40_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial01_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial01_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial01_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial01_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial01_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial01_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial01_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial01_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial02_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial02_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial02_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial02_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial02_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial02_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial02_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial02_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial03_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial03_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial03_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial03_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial03_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial03_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial03_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial03_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial04_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial04_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial04_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial04_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial04_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial04_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial04_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial04_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial05_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial05_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial05_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial05_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial05_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial05_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial05_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial05_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial06_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial06_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial06_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial06_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial06_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial06_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial06_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial06_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial07_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial07_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial07_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial07_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial07_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial07_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial07_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial07_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial08_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial08_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial08_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial08_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial08_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial08_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial08_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial08_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial09_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial09_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial09_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial09_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial09_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial09_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial09_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial09_playerB.png',
#   'class': 'Cooperation'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial10_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-A-Single-EYE_trial10_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial10_player.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-B-Single-EYE_trial10_observer.png',
#   'class': 'Single'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial10_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Comp-EYE_trial10_playerB.png',
#   'class': 'Competition'},
#  {'image1': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial10_playerA.png',
#   'image2': 'heatmapOn_trajOn_Pair-18-Coop-EYE_trial10_playerB.png',
#   'class': 'Cooperation'},
#  ...]

# %% [markdown]
# ## Step 3. Load Dataset

# %%
dataset = load_dataset("json", data_files="./image_gt.json", split="train")
datasets = dataset.train_test_split(test_size=0.1)
datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image1', 'image2', 'class'],
#         num_rows: 4176
#     })
#     test: Dataset({
#         features: ['image1', 'image2', 'class'],
#         num_rows: 464
#     })
# })

# %% [markdown]
# ## Step 4. Preprocess Data

# %%
import torch
from transformers import ViTImageProcessor, BertTokenizer, VisionEncoderDecoderModel


#model = VisionEncoderDecoderModel.from_pretrained("nlpconnect/vit-gpt2-image-captioning")

image_processor = ViTImageProcessor.from_pretrained("google/vit-base-patch16-224-in21k")
tokenizer = BertTokenizer.from_pretrained("google-bert/bert-base-uncased")

def process_function(example_batch):
    # 確保 batch 中的資料長度一致
    assert len(example_batch['image1']) == len(example_batch['class']), "Batch data length mismatch"

    # 批次處理圖片
    images = []
    valid_indices = []
    for idx, image_name in enumerate(example_batch['image1']):
        img_path = "./heatmapOn_trajOn/" + image_name
        try:
            image = Image.open(img_path)
            images.append(image_processor(image, return_tensors="pt").pixel_values.squeeze())
            valid_indices.append(idx)
        except Exception as e:
            print(f"Error processing image {image_name}: {e}")
            continue

    # 保留與成功處理的圖片對應的文本
    filtered_texts = [example_batch["class"][i] for i in valid_indices]
    labels = tokenizer(filtered_texts, return_tensors="pt", padding="max_length", max_length=8)
    #inputs = tokenizer(filtered_texts, return_tensors="pt", padding="max_length", truncation=True, max_length=8)

    # 檢查是否圖片與文本長度一致
    if len(images) != len(labels):
        print("Skipping batch due to length mismatch between images and input_ids.")
        return {}  # 返回空字典來跳過這個批次

    # 回傳處理結果
    example_batch["pixel_values"] = torch.stack(images)  # 堆疊成 tensor
    example_batch["input_ids"] = labels
    #example_batch["attention_mask"] = inputs.attention_mask"  # 添加attention_mask
    return example_batch

tokenized_datasets = datasets.map(process_function, batched=True, batch_size=8, remove_columns=datasets["train"].column_names)
tokenized_datasets
# Out:
# Map:   0%|                              | 8/4176 [00:00<01:57, 35.38 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   0%|                             | 16/4176 [00:00<02:00, 34.63 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   1%|▏                            | 24/4176 [00:00<02:00, 34.55 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   1%|▏                            | 32/4176 [00:00<01:59, 34.81 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   1%|▎                            | 40/4176 [00:01<01:58, 34.76 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   1%|▎                            | 48/4176 [00:01<01:58, 34.87 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   2%|▍                            | 64/4176 [00:01<01:53, 36.29 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Error processing image heatmapOn_trajOn_Pair-18-B-Single-EYE_trial12_player.png: [Errno 2] No such file or directory: './heatmapOn_trajOn/heatmapOn_trajOn_Pair-18-B-Single-EYE_trial12_player.png'
# Skipping batch due to length mismatch between images and input_ids.
# Map:   2%|▌                            | 72/4176 [00:02<01:54, 35.92 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   2%|▌                            | 80/4176 [00:02<01:53, 35.97 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   2%|▌                            | 88/4176 [00:02<01:54, 35.59 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   2%|▋                            | 96/4176 [00:02<01:54, 35.54 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   2%|▋                           | 104/4176 [00:02<01:55, 35.32 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   3%|▊                           | 112/4176 [00:03<01:54, 35.39 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   3%|▊                           | 120/4176 [00:03<01:54, 35.57 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   3%|▊                           | 128/4176 [00:03<01:54, 35.44 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   3%|▉                           | 136/4176 [00:03<01:54, 35.35 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   3%|▉                           | 144/4176 [00:04<01:54, 35.32 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   4%|█                           | 152/4176 [00:04<01:54, 35.03 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   4%|█                           | 160/4176 [00:04<01:56, 34.55 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   4%|█▏                          | 168/4176 [00:04<01:55, 34.78 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   4%|█▏                          | 176/4176 [00:05<01:57, 34.16 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   4%|█▏                          | 184/4176 [00:05<01:56, 34.34 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   5%|█▎                          | 192/4176 [00:05<01:55, 34.47 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   5%|█▎                          | 200/4176 [00:05<01:57, 33.84 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   5%|█▍                          | 208/4176 [00:05<01:56, 34.07 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   5%|█▍                          | 216/4176 [00:06<01:54, 34.73 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   5%|█▌                          | 224/4176 [00:06<01:53, 34.86 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   6%|█▌                          | 232/4176 [00:06<01:53, 34.79 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   6%|█▌                          | 240/4176 [00:06<01:53, 34.66 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   6%|█▋                          | 248/4176 [00:07<01:55, 34.11 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# Map:   6%|█▋                          | 256/4176 [00:07<01:55, 33.96 examples/s]
# Skipping batch due to length mismatch between images and input_ids.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 43
#      40     #example_batch["attention_mask"] = inputs.attention_mask"  # 添加attention_mask
#      41     return example_batch
# ---> 43 tokenized_datasets = datasets.map(process_function, batched=True, batch_size=8, remove_columns=datasets["train"].column_names)
#      44 tokenized_datasets
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/datasets/dataset_dict.py:870, in DatasetDict.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_names, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, desc)
#     866 if cache_file_names is None:
#     867     cache_file_names = {k: None for k in self}
#     868 return DatasetDict(
#     869     {
# --> 870         k: dataset.map(
#     871             function=function,
#     872             with_indices=with_indices,
#     873             with_rank=with_rank,
#     874             input_columns=input_columns,
#     875             batched=batched,
#     876             batch_size=batch_size,
#     877             drop_last_batch=drop_last_batch,
#     878             remove_columns=remove_columns,
#     879             keep_in_memory=keep_in_memory,
#     880             load_from_cache_file=load_from_cache_file,
#     881             cache_file_name=cache_file_names[k],
#     882             writer_batch_size=writer_batch_size,
#     883             features=features,
#     884             disable_nullable=disable_nullable,
#     885             fn_kwargs=fn_kwargs,
#     886             num_proc=num_proc,
#     887             desc=desc,
#     888         )
#     889         for k, dataset in self.items()
#     890     }
#     891 )
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/datasets/arrow_dataset.py:602, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     600     self: "Dataset" = kwargs.pop("self")
#     601 # apply actual function
# --> 602 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     603 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     604 for dataset in datasets:
#     605     # Remove task templates if a column mapping of the template is no longer valid
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/datasets/arrow_dataset.py:567, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     560 self_format = {
#     561     "type": self._format_type,
#     562     "format_kwargs": self._format_kwargs,
#     563     "columns": self._format_columns,
#     564     "output_all_columns": self._output_all_columns,
#     565 }
#     566 # apply actual function
# --> 567 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     568 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     569 # re-apply format to the output
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/datasets/arrow_dataset.py:3167, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3161 if transformed_dataset is None:
#    3162     with hf_tqdm(
#    3163         unit=" examples",
#    3164         total=pbar_total,
#    3165         desc=desc or "Map",
#    3166     ) as pbar:
# -> 3167         for rank, done, content in Dataset._map_single(**dataset_kwargs):
#    3168             if done:
#    3169                 shards_done += 1
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/datasets/arrow_dataset.py:3558, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset)
#    3554 indices = list(
#    3555     range(*(slice(i, i + batch_size).indices(shard.num_rows)))
#    3556 )  # Something simpler?
#    3557 try:
# -> 3558     batch = apply_function_on_filtered_inputs(
#    3559         batch,
#    3560         indices,
#    3561         check_same_num_examples=len(shard.list_indexes()) > 0,
#    3562         offset=offset,
#    3563     )
#    3564 except NumExamplesMismatchError:
#    3565     raise DatasetTransformationNotAllowedError(
#    3566         "Using `.map` in batched mode on a dataset with attached indexes is allowed only if it doesn't create or remove existing examples. You can first run `.drop_index() to remove your index and then re-add it."
#    3567     ) from None
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/datasets/arrow_dataset.py:3427, in Dataset._map_single.<locals>.apply_function_on_filtered_inputs(pa_inputs, indices, check_same_num_examples, offset)
#    3425 if with_rank:
#    3426     additional_args += (rank,)
# -> 3427 processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3428 if isinstance(processed_inputs, LazyDict):
#    3429     processed_inputs = {
#    3430         k: v for k, v in processed_inputs.data.items() if k not in processed_inputs.keys_to_format
#    3431     }
#
# Cell In[20], line 21, in process_function(example_batch)
#      19 try:
#      20     image = Image.open(img_path)
# ---> 21     images.append(image_processor(image, return_tensors="pt").pixel_values.squeeze())
#      22     valid_indices.append(idx)
#      23 except Exception as e:
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/transformers/image_processing_utils.py:41, in BaseImageProcessor.__call__(self, images, **kwargs)
#      39 def __call__(self, images, **kwargs) -> BatchFeature:
#      40     """Preprocess an image or a batch of images."""
# ---> 41     return self.preprocess(images, **kwargs)
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/transformers/utils/generic.py:852, in filter_out_non_signature_kwargs.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     843         cls_prefix = ""
#     845     warnings.warn(
#     846         f"The following named arguments are not valid for `{cls_prefix}{func.__name__}`"
#     847         f" and were ignored: {invalid_kwargs_names}",
#     848         UserWarning,
#     849         stacklevel=2,
#     850     )
# --> 852 return func(*args, **valid_kwargs)
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/transformers/models/vit/image_processing_vit.py:237, in ViTImageProcessor.preprocess(self, images, do_resize, size, resample, do_rescale, rescale_factor, do_normalize, image_mean, image_std, return_tensors, data_format, input_data_format)
#     225 validate_preprocess_arguments(
#     226     do_rescale=do_rescale,
#     227     rescale_factor=rescale_factor,
#    (...)
#     233     resample=resample,
#     234 )
#     236 # All transformations expect numpy arrays.
# --> 237 images = [to_numpy_array(image) for image in images]
#     239 if is_scaled_image(images[0]) and do_rescale:
#     240     logger.warning_once(
#     241         "It looks like you are trying to rescale already rescaled images. If the input"
#     242         " images have pixel values between 0 and 1, set `do_rescale=False` to avoid rescaling them again."
#     243     )
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/transformers/image_utils.py:216, in to_numpy_array(img)
#     213     raise ValueError(f"Invalid image type: {type(img)}")
#     215 if is_vision_available() and isinstance(img, PIL.Image.Image):
# --> 216     return np.array(img)
#     217 return to_numpy(img)
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/PIL/Image.py:681, in Image.__array_interface__(self)
#     679         new["data"] = self.tobytes("raw", "L")
#     680     else:
# --> 681         new["data"] = self.tobytes()
#     682 except Exception as e:
#     683     if not isinstance(e, (MemoryError, RecursionError)):
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/PIL/Image.py:740, in Image.tobytes(self, encoder_name, *args)
#     737 if encoder_name == "raw" and args == ():
#     738     args = self.mode
# --> 740 self.load()
#     742 if self.width == 0 or self.height == 0:
#     743     return b""
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/PIL/ImageFile.py:291, in ImageFile.load(self)
#     288         raise OSError(msg)
#     290 b = b + s
# --> 291 n, err_code = decoder.decode(b)
#     292 if n < 0:
#     293     break
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step5. Load Model

# %%
model = VisionEncoderDecoderModel.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
# Out:
# VisionEncoderDecoderModel has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.

# %% [markdown]
# ## Step 6. Create Training Arguments

# %%
from transformers import Trainer, TrainingArguments


# 載入模型、tokenizer、image processor
model = VisionEncoderDecoderModel.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
#tokenizer = GPT2TokenizerFast.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
#image_processor = ViTImageProcessor.from_pretrained("nlpconnect/vit-gpt2-image-captioning")

# 設置模型生成參數
model.config.decoder_start_token_id = tokenizer.cls_token_id
model.config.pad_token_id = tokenizer.pad_token_id

# 設置訓練參數
training_args = TrainingArguments(
    output_dir="./output",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=3,
    save_steps=10_000,
    save_total_limit=2,
    push_to_hub=False,  # 禁用自動登錄到 Hugging Face Hub
    report_to="none"  # 禁用所有外部服務的報告
    #logging_dir='./logs',
    #logging_steps=500,
)

# 初始化Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
)

# 開始訓練
trainer.train()
# Out:
# /home/cnelabai/anaconda3/envs/hugging/lib/python3.12/site-packages/torch/cuda/__init__.py:654: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 36
#      28 trainer = Trainer(
#      29     model=model,
#      30     args=training_args,
#      31     train_dataset=tokenized_datasets["train"],
#      32     eval_dataset=tokenized_datasets["test"],
#      33 )
#      35 # 開始訓練
# ---> 36 trainer.train()
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/transformers/trainer.py:2052, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2050         hf_hub_utils.enable_progress_bars()
#    2051 else:
# -> 2052     return inner_training_loop(
#    2053         args=args,
#    2054         resume_from_checkpoint=resume_from_checkpoint,
#    2055         trial=trial,
#    2056         ignore_keys_for_eval=ignore_keys_for_eval,
#    2057     )
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/transformers/trainer.py:2388, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2385     self.control = self.callback_handler.on_step_begin(args, self.state, self.control)
#    2387 with self.accelerator.accumulate(model):
# -> 2388     tr_loss_step = self.training_step(model, inputs)
#    2390 if (
#    2391     args.logging_nan_inf_filter
#    2392     and not is_torch_xla_available()
#    2393     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2394 ):
#    2395     # if loss is nan or inf simply add the average of previous logged losses
#    2396     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/transformers/trainer.py:3485, in Trainer.training_step(self, model, inputs)
#    3482     return loss_mb.reduce_mean().detach().to(self.args.device)
#    3484 with self.compute_loss_context_manager():
# -> 3485     loss = self.compute_loss(model, inputs)
#    3487 del inputs
#    3488 if (
#    3489     self.args.torch_empty_cache_steps is not None
#    3490     and self.state.global_step % self.args.torch_empty_cache_steps == 0
#    3491 ):
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/transformers/trainer.py:3532, in Trainer.compute_loss(self, model, inputs, return_outputs)
#    3530 else:
#    3531     labels = None
# -> 3532 outputs = model(**inputs)
#    3533 # Save past state if it exists
#    3534 # TODO: this needs to be fixed and made cleaner later.
#    3535 if self.args.past_index >= 0:
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/transformers/models/vision_encoder_decoder/modeling_vision_encoder_decoder.py:615, in VisionEncoderDecoderModel.forward(self, pixel_values, decoder_input_ids, decoder_attention_mask, encoder_outputs, past_key_values, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, **kwargs)
#     610     decoder_input_ids = shift_tokens_right(
#     611         labels, self.config.pad_token_id, self.config.decoder_start_token_id
#     612     )
#     614 # Decode
# --> 615 decoder_outputs = self.decoder(
#     616     input_ids=decoder_input_ids,
#     617     attention_mask=decoder_attention_mask,
#     618     encoder_hidden_states=encoder_hidden_states,
#     619     encoder_attention_mask=encoder_attention_mask,
#     620     inputs_embeds=decoder_inputs_embeds,
#     621     output_attentions=output_attentions,
#     622     output_hidden_states=output_hidden_states,
#     623     use_cache=use_cache,
#     624     past_key_values=past_key_values,
#     625     return_dict=return_dict,
#     626     **kwargs_decoder,
#     627 )
#     629 # Compute loss independent from decoder (as some shift the logits inside them)
#     630 loss = None
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/transformers/models/gpt2/modeling_gpt2.py:1316, in GPT2LMHeadModel.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1308 r"""
#    1309 labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1310     Labels for language modeling. Note that the labels **are shifted** inside the model, i.e. you can set
#    1311     `labels = input_ids` Indices are selected in `[-100, 0, ..., config.vocab_size]` All labels set to `-100`
#    1312     are ignored (masked), the loss is only computed for labels in `[0, ..., config.vocab_size]`
#    1313 """
#    1314 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1316 transformer_outputs = self.transformer(
#    1317     input_ids,
#    1318     past_key_values=past_key_values,
#    1319     attention_mask=attention_mask,
#    1320     token_type_ids=token_type_ids,
#    1321     position_ids=position_ids,
#    1322     head_mask=head_mask,
#    1323     inputs_embeds=inputs_embeds,
#    1324     encoder_hidden_states=encoder_hidden_states,
#    1325     encoder_attention_mask=encoder_attention_mask,
#    1326     use_cache=use_cache,
#    1327     output_attentions=output_attentions,
#    1328     output_hidden_states=output_hidden_states,
#    1329     return_dict=return_dict,
#    1330 )
#    1331 hidden_states = transformer_outputs[0]
#    1333 # Set device for model parallelism
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/hugging/lib/python3.12/site-packages/transformers/models/gpt2/modeling_gpt2.py:1011, in GPT2Model.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict)
#    1009     batch_size = inputs_embeds.shape[0]
#    1010 else:
# -> 1011     raise ValueError("You have to specify either input_ids or inputs_embeds")
#    1013 device = input_ids.device if input_ids is not None else inputs_embeds.device
#    1015 if token_type_ids is not None:
#
# ValueError: You have to specify either input_ids or inputs_embeds

# %%
print(tokenized_datasets["train"].column_names)
# Out:
# ['pixel_values', 'input_ids', 'attention_mask']
